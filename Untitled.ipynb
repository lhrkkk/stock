# %%
# %matplotlib inline
import pyfolio as pf

# %%
stock_rets = pf.utils.get_symbol_rets('FB')

# %%
stock_rets
# Out:
# Date
# 2012-05-21 00:00:00+00:00   -0.109861
# 2012-05-22 00:00:00+00:00   -0.089039
# 2012-05-23 00:00:00+00:00    0.032258
# 2012-05-24 00:00:00+00:00    0.032187
# 2012-05-25 00:00:00+00:00   -0.033909
# 2012-05-29 00:00:00+00:00   -0.096208
# 2012-05-30 00:00:00+00:00   -0.022538
# 2012-05-31 00:00:00+00:00    0.050018
# 2012-06-01 00:00:00+00:00   -0.063514
# 2012-06-04 00:00:00+00:00   -0.029581
# 2012-06-05 00:00:00+00:00   -0.038290
# 2012-06-06 00:00:00+00:00    0.036335
# 2012-06-07 00:00:00+00:00   -0.018650
# 2012-06-08 00:00:00+00:00    0.030027
# 2012-06-11 00:00:00+00:00   -0.003321
# 2012-06-12 00:00:00+00:00    0.014439
# 2012-06-13 00:00:00+00:00   -0.004745
# 2012-06-14 00:00:00+00:00    0.037404
# 2012-06-15 00:00:00+00:00    0.060799
# 2012-06-18 00:00:00+00:00    0.046651
# 2012-06-19 00:00:00+00:00    0.015918
# 2012-06-20 00:00:00+00:00   -0.009715
# 2012-06-21 00:00:00+00:00    0.007595
# 2012-06-22 00:00:00+00:00    0.038002
# ...

# %%
pf.create_returns_tear_sheet(stock_rets)
# Out:
# Entire data start date: 2012-05-21 00:00:00+00:00
# Entire data end date: 2015-09-25 00:00:00+00:00
#
#
# Backtest Months: 40
#                    Backtest
# annual_return          0.36
# annual_volatility      0.44
# sharpe_ratio           0.82
# calmar_ratio           0.75
# stability              0.88
# max_drawdown          -0.48
# omega_ratio            1.17
# sortino_ratio          1.56
# skewness               1.75
# kurtosis              19.22
# alpha                  0.21
# beta                   1.00
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-899e9d55585c> in <module>()
# ----> 1 pf.create_returns_tear_sheet(stock_rets)
#
# /Users/lhr/anaconda/lib/python2.7/site-packages/pyfolio/plotting.pyc in call_w_context(*args, **kwargs)
#      40         if set_context:
#      41             with context():
# ...
